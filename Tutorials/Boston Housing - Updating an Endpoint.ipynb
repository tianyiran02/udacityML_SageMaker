# %% [markdown]
# # 预测波士顿房价
#
# ## 使用 SageMaker 更新模型
#
# _机器学习工程师纳米学位课程 | 部署_
#
# ---
#
# 在此 notebook 中，我们将继续使用[波士顿房价数据集](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html)。我们的目标是训练两个不同的模型，并使用 SageMaker 让部署的端点切换使用两个模型中的某个模型。使用 SageMaker 完成这些操作的优势之一是我们可以更新模型，但是不中断服务。我们可以继续向端点发送数据，并且端点始终不会消失。
#
# ## 一般步骤
#
# 通常，在 notebook 实例中使用 SageMaker 时，你需要完成以下步骤。当然，并非每个项目都要完成每一步。此外，有很多步骤有很大的变化余地，你将在这些课程中发现这一点。
#
# 1. 下载或检索数据。
# 2. 处理/准备数据。
# 3. 将处理的数据上传到 S3。
# 4. 训练所选的模型。
# 5. 测试训练的模型（通常使用批转换作业）。
# 6. 部署训练的模型。
# 7. 使用部署的模型。
#
# 在此 notebook 中，我们将跳过第 5 步 - 测试模型。此外，我们将用不同的模型多次执行第 4、6 和 7 步。

# %% [markdown]
# ## 第 0 步：设置 notebook
#
# 先进行必要的设置以运行 notebook。首先，加载所需的所有 Python 模块。

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd

from pprint import pprint
import matplotlib.pyplot as plt
from time import gmtime, strftime

from sklearn.datasets import load_boston
import sklearn.model_selection

# %% [markdown]
# 除了上面的模块之外，我们还需要导入将使用的各种 SageMaker 模块。

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer

# This is an object that represents the SageMaker session that we are currently operating in. This
# object contains some useful information that we will need to access later such as our region.
session = sagemaker.Session()

# This is an object that represents the IAM role that we are currently assigned. When we construct
# and launch the training job later we will need to tell it what IAM role it should have. Since our
# use case is relatively simple we will simply assign the training job the role we currently have.
role = get_execution_role()

# %% [markdown]
# ## 第 1 步：下载数据
#
# 幸运的是，我们可以使用 sklearn 检索数据集，所以这一步相对比较简单。

# %%
boston = load_boston()

# %% [markdown]
# ## 第 2 步：准备和拆分数据
#
# 因为使用的是整洁的表格数据，所以不需要进行任何处理。但是，我们需要将数据集中的各行拆分成训练集、测试集和验证集。

# %%
# First we package up the input data and the target variable (the median value) as pandas dataframes. This
# will make saving the data to a file a little easier later on.

X_bos_pd = pd.DataFrame(boston.data, columns=boston.feature_names)
Y_bos_pd = pd.DataFrame(boston.target)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X_bos_pd, Y_bos_pd, test_size=0.33)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# ## 第 3 步：将训练和验证文件上传到 S3
#
# 使用 SageMaker 创建训练作业后，进行训练操作的容器会执行。此容器可以访问存储在 S3 上的数据。所以我们需要将用来训练的数据上传到 S3。我们可以使用 SageMaker API 完成这一步，它会在后台自动处理一些步骤。
#
# ### 将数据保存到本地
#
# 首先，我们需要创建训练和验证 csv 文件，并将这些文件上传到 S3。

# %%
# This is our local data directory. We need to make sure that it exists.
data_dir = '../data/boston'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# We use pandas to save our train and validation data to csv files. Note that we make sure not to include header
# information or an index as this is required by the built in algorithms provided by Amazon. Also, it is assumed
# that the first entry in each row is the target variable.

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %% [markdown]
# ### 上传到 S3
#
# 因为目前正在 SageMaker 会话中运行，所以可以使用代表此会话的对象将数据上传到默认的 S3 存储桶中。注意，建议提供自定义 prefix（即 S3 文件夹），以防意外地破坏了其他 notebook 或项目上传的数据。

# %%
prefix = 'boston-update-endpoints'

val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ## 第 4 步：训练 XGBoost 模型
#
# 将训练和验证数据上传到 S3 后，我们可以构建 XGBoost 模型并训练它。我们将使用高阶 SageMaker API 完成这一步，这样的话代码更容易读懂，但是灵活性较差。
#
# 为了构建一个评估器（即我们要训练的对象），我们需要提供训练代码所在的容器的位置。因为我们使用的是内置算法，所以这个容器由 Amazon 提供。但是，容器的完整名称比较长，取决于我们运行所在的区域。幸运的是，SageMaker 提供了一个实用方法，叫做 `get_image_uri`，它可以为我们构建镜像名称。
#
# 为了使用 `get_image_uri` 方法，我们需要向其提供当前所在区域（可以从 session 对象中获得），以及要使用的算法的名称。在此 notebook 中，我们将使用 XGBoost，但是你也可以尝试其他算法。[常见参数](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html)中列出了 Amazon 的内置算法。

# %%
# As stated above, we use this utility method to construct the image name for the training container.
xgb_container = get_image_uri(session.boto_region_name, 'xgboost')

# Now that we know which container to use, we can construct the estimator object.
xgb = sagemaker.estimator.Estimator(xgb_container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %% [markdown]
# 在要求 SageMaker 开始训练作业之前，我们需要设置模型超参数。如果使用 XGBoost 算法，可以设置的超参数有很多，以下只是其中几个。如果你想修改下面的超参数或修改其他超参数，请参阅 [XGBoost 超参数页面](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html)

# %%
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %% [markdown]
# 完全设置好 estimator 对象后，可以训练它了。我们需要告诉 SageMaker 输入数据是 csv 格式，然后调用 `fit` 方法。

# %%
# This is a wrapper around the location of our train and validation data, to make sure that SageMaker
# knows our data is in csv format.
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-03-31 11:00:10 Starting - Starting the training job...
# 2020-03-31 11:00:12 Starting - Launching requested ML instances......
# 2020-03-31 11:01:14 Starting - Preparing the instances for training...
# 2020-03-31 11:02:06 Downloading - Downloading input data...
# 2020-03-31 11:02:38 Training - Downloading the training image...
# 2020-03-31 11:03:10 Uploading - Uploading generated training model
# 2020-03-31 11:03:10 Completed - Training job completed
# Arguments: train
# [2020-03-31:11:02:58:INFO] Running standalone xgboost training.
# [2020-03-31:11:02:58:INFO] File size need to be processed in the node: 0.02mb. Available memory size in the node: 8511.29mb
# [2020-03-31:11:02:58:INFO] Determined delimiter of CSV input is ','
# [11:02:58] S3DistributionType set as FullyReplicated
# [11:02:58] 227x13 matrix with 2951 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-03-31:11:02:58:INFO] Determined delimiter of CSV input is ','
# [11:02:58] S3DistributionType set as FullyReplicated
# [11:02:58] 112x13 matrix with 1456 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:20.2794#011validation-rmse:20.0214
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [1]#011train-rmse:16.5003#011validation-rmse:16.5798
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [2]#011train-rmse:13.4344#011validation-rmse:13.8862
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [3]#011train-rmse:11.0285#011validation-rmse:11.7956
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [4]#011train-rmse:9.05701#011validation-rmse:9.98748
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [5]#011train-rmse:7.47402#011validation-rmse:8.67101
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:6.23239#011validation-rmse:7.77086
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:5.17631#011validation-rmse:7.04334
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:4.38485#011validation-rmse:6.47451
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:3.75358#011validation-rmse:6.05673
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:3.2673#011validation-rmse:5.79069
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [11]#011train-rmse:2.90225#011validation-rmse:5.59079
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:2.5899#011validation-rmse:5.47965
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:2.35862#011validation-rmse:5.35926
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:2.18054#011validation-rmse:5.24586
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:2.02842#011validation-rmse:5.09899
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [16]#011train-rmse:1.90198#011validation-rmse:5.08057
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:1.78008#011validation-rmse:5.05129
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [18]#011train-rmse:1.67402#011validation-rmse:4.99838
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [19]#011train-rmse:1.58923#011validation-rmse:4.96686
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [20]#011train-rmse:1.52805#011validation-rmse:4.9439
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [21]#011train-rmse:1.48153#011validation-rmse:4.9561
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [22]#011train-rmse:1.42673#011validation-rmse:4.94951
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [23]#011train-rmse:1.39369#011validation-rmse:4.93534
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [24]#011train-rmse:1.35787#011validation-rmse:4.92362
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [25]#011train-rmse:1.32127#011validation-rmse:4.92658
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [26]#011train-rmse:1.29482#011validation-rmse:4.92404
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [27]#011train-rmse:1.24576#011validation-rmse:4.91591
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [28]#011train-rmse:1.22037#011validation-rmse:4.90137
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:1.20424#011validation-rmse:4.90119
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [30]#011train-rmse:1.18402#011validation-rmse:4.88368
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=4
# [31]#011train-rmse:1.14545#011validation-rmse:4.86756
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [32]#011train-rmse:1.10614#011validation-rmse:4.86687
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [33]#011train-rmse:1.08881#011validation-rmse:4.86869
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [34]#011train-rmse:1.0862#011validation-rmse:4.87298
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 16 pruned nodes, max_depth=3
# [35]#011train-rmse:1.07863#011validation-rmse:4.86168
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 12 pruned nodes, max_depth=2
# [36]#011train-rmse:1.06715#011validation-rmse:4.85629
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [37]#011train-rmse:1.04453#011validation-rmse:4.8514
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [38]#011train-rmse:1.03671#011validation-rmse:4.83554
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 14 pruned nodes, max_depth=2
# [39]#011train-rmse:1.02859#011validation-rmse:4.84704
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 22 pruned nodes, max_depth=5
# [40]#011train-rmse:1.01478#011validation-rmse:4.84565
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 18 pruned nodes, max_depth=4
# [41]#011train-rmse:1.00192#011validation-rmse:4.83968
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [42]#011train-rmse:0.982331#011validation-rmse:4.83828
# [11:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [43]#011train-rmse:0.972531#011validation-rmse:4.8243
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [44]#011train-rmse:0.9626#011validation-rmse:4.83333
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [45]#011train-rmse:0.962567#011validation-rmse:4.83338
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [46]#011train-rmse:0.946445#011validation-rmse:4.82459
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 22 pruned nodes, max_depth=2
# [47]#011train-rmse:0.943171#011validation-rmse:4.82232
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [48]#011train-rmse:0.943173#011validation-rmse:4.82231
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [49]#011train-rmse:0.932991#011validation-rmse:4.80942
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [50]#011train-rmse:0.920117#011validation-rmse:4.82204
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 18 pruned nodes, max_depth=3
# [51]#011train-rmse:0.912572#011validation-rmse:4.82406
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 16 pruned nodes, max_depth=2
# [52]#011train-rmse:0.906344#011validation-rmse:4.82517
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [53]#011train-rmse:0.906336#011validation-rmse:4.82514
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 24 pruned nodes, max_depth=0
# [54]#011train-rmse:0.906376#011validation-rmse:4.82525
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 26 pruned nodes, max_depth=0
# [55]#011train-rmse:0.906324#011validation-rmse:4.82509
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=4
# [56]#011train-rmse:0.886149#011validation-rmse:4.83075
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [57]#011train-rmse:0.876259#011validation-rmse:4.8364
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [58]#011train-rmse:0.876243#011validation-rmse:4.83628
# [11:02:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 24 pruned nodes, max_depth=2
# [59]#011train-rmse:0.871816#011validation-rmse:4.83309
# Stopping. Best iteration:
# [49]#011train-rmse:0.932991#011validation-rmse:4.80942
# Training seconds: 64
# Billable seconds: 64

# %% [markdown]
# ## 第 5 步：测试训练过的模型
#
# 我们暂时将跳过这一步。
#
#
# ## 第 6 (A) 步：部署训练过的模型
#
# 虽然我们使用了高阶方法构建和训练 XGBoost 模型，但是我们将使用低阶方法部署模型。原因之一是可以更好地控制端点的构建方式。在后面构建更高级的端点时你就会明白的。
#
# ### 构建模型
#
# 在部署模型之前，我们需要先创建模型。我们之前使用的 `fit` 方法创建了一些模型工件，我们可以使用这些工件构建模型对象。

# %%
# Remember that a model needs to have a unique name
xgb_model_name = "boston-update-xgboost-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the xgboost container that we used for training
# can also be used for inference and the model artifacts come from the previous call to fit.
xgb_primary_container = {
    "Image": xgb_container,
    "ModelDataUrl": xgb.model_data
}

# And lastly we construct the SageMaker model
xgb_model_info = session.sagemaker_client.create_model(
                                ModelName = xgb_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = xgb_primary_container)

# %% [markdown]
# ### 创建端点配置
#
# 创建了模型之后，我们可以创建端点了。我们需要首先创建端点配置，实际上就是 SageMaker 用来构建端点本身所使用的蓝图。

# %%
# As before, we need to give our endpoint configuration a name which should be unique
xgb_endpoint_config_name = "boston-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": xgb_model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# ### 部署端点
#
# 创建了端点配置后，我们可以要求 SageMaker 构建端点了。
#
# **注意：**再次友好提醒你，你即将部署端点。使用完毕后，请记得关闭端点！

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = xgb_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------!

# %% [markdown]
# ## 第 7 (A) 步：使用模型
#
# 训练并部署模型后，我们可以向其发送一些测试数据，看看结果如何。

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0d3a25f8>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Tue, 31 Mar 2020 11:12:21 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '4e0acaf7-3c84-4490-b92a-ef317e907bbd'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '4e0acaf7-3c84-4490-b92a-ef317e907bbd',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '25.4541683197'

# %%
Y_test.values[0]
# Out:
# array([24.6])

# %% [markdown]
# ## 关闭端点
#
# 现在我们知道 XGBoost 端点能运行，我们将关闭端点。稍后我们将再使用它。

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '7b2cf3dd-d894-4fa4-ad24-2512c94ffcd4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '7b2cf3dd-d894-4fa4-ad24-2512c94ffcd4',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Tue, 31 Mar 2020 11:12:29 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## 第 4 (B) 步：训练线性模型
#
# 假设对于我们所在的环境，我们之前训练的 XGBoost 模型成本变得非常高。也许对端点的调用次数增加了，使用 XGBoost 模型进行推理所需的时间变得很长。
#
# 一种可能的解决方法是训练一个更简单的模型，看看它能否几乎达到一样的性能。我们将构建一个线性模型。构建流程与之前创建的 XGBoost 模型一样，但是我们需要设置不同的超参数。

# %%
# Similar to the XGBoost model, we will use the utility method to construct the image name for the training container.
linear_container = get_image_uri(session.boto_region_name, 'linear-learner')

# Now that we know which container to use, we can construct the estimator object.
linear = sagemaker.estimator.Estimator(linear_container, # The name of the training container
                                        role,      # The IAM role to use (our current role in this case)
                                        train_instance_count=1, # The number of instances to use for training
                                        train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                        output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                            # Where to save the output (the model artifacts)
                                        sagemaker_session=session) # The current SageMaker session

# %% [markdown]
# 在要求 SageMaker 训练模型之前，我们需要设置一些超参数。因为我们使用的是线性模型，所以要设置的超参数少了很多。详情请参阅[线性模型超参数](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)页面

# %%
linear.set_hyperparameters(feature_dim=13, # Our data has 13 feature columns
                           predictor_type='regressor', # We wish to create a regression model
                           mini_batch_size=200) # Here we set how many samples to look at in each iteration

# %% [markdown]
# 设置好超参数后，我们可以要求 SageMaker 使线性模型拟合我们的数据。

# %%
linear.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-03-31 11:12:39 Starting - Starting the training job...
# 2020-03-31 11:12:40 Starting - Launching requested ML instances...
# 2020-03-31 11:13:39 Starting - Preparing the instances for training.........
# 2020-03-31 11:15:02 Downloading - Downloading input data...
# 2020-03-31 11:15:40 Training - Training image download completed. Training in progress.
# 2020-03-31 11:15:40 Uploading - Uploading generated training model.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/31/2020 11:15:37 INFO 140708599981888] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/31/2020 11:15:37 INFO 140708599981888] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'200', u'predictor_type': u'regressor'}
# [03/31/2020 11:15:37 INFO 140708599981888] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/31/2020 11:15:37 WARNING 140708599981888] Loggers have already been setup.
# Process 1 is a worker.
# [03/31/2020 11:15:37 INFO 140708599981888] Using default worker.
# [03/31/2020 11:15:37 INFO 140708599981888] Create Store: local
# [03/31/2020 11:15:38 INFO 140708599981888] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ff8f476dad0>
# [03/31/2020 11:15:38 INFO 140708599981888] Scaling model computed with parameters:
#  {'stdev_weight':
# [6.97022963e+00 2.52476482e+01 6.95764875e+00 2.71293193e-01
#  1.20491184e-01 7.09627390e-01 2.84240894e+01 2.10109329e+00
#  8.24166775e+00 1.61919022e+02 2.24376893e+00 8.12994843e+01
#  6.99692345e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [9.830519]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [23.650501]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [2.9195821e+00 1.2715000e+01 1.1018650e+01 7.9999998e-02 5.5254549e-01
#  6.4175649e+00 7.0140999e+01 3.7739320e+00 8.9300003e+00 3.9667001e+02
#  1.8076500e+01 3.6142465e+02 1.2441751e+01]
# <NDArray 13 @cpu(0)>}
# [03/31/2020 11:15:38 INFO 140708599981888] nvidia-smi took: 0.0252590179443 secs to identify 0 gpus
# [03/31/2020 11:15:38 INFO 140708599981888] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1585653338.11281, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1585653338.112771}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9526938629150391, "sum": 0.9526938629150391, "min": 0.9526938629150391}}, "EndTime": 1585653338.147624, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1585653338.147564}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8635884857177735, "sum": 0.8635884857177735, "min": 0.8635884857177735}}, "EndTime": 1585653338.147694, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1585653338.147679}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3550112915039063, "sum": 1.3550112915039063, "min": 1.3550112915039063}}, "EndTime": 1585653338.147762, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1585653338
"Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.258462}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.24338204520089, "sum": 84.24338204520089, "min": 84.24338204520089}}, "EndTime": 1585653339.258527, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.258514}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 75.79986572265625, "sum": 75.79986572265625, "min": 75.79986572265625}}, "EndTime": 1585653339.258609, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.258593}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 88.36393519810268, "sum": 88.36393519810268, "min": 88.36393519810268}}, "EndTime": 1585653339.258664, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.258649}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 86.38883754185268, "sum": 86.38883754185268, "min": 86.38883754185268}}, "EndTime": 1585653339.258714, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.2587}
#
# [03/31/2020 11:15:39 INFO 140708599981888] #quality_metric: host=algo-1, epoch=13, validation mse_objective <loss>=52.3473118373
# [03/31/2020 11:15:39 INFO 140708599981888] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=42.2806178502
# [03/31/2020 11:15:39 INFO 140708599981888] Early stop condition met. Stopping training.
# [03/31/2020 11:15:39 INFO 140708599981888] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Total Records Seen": {"count": 1, "max": 3605, "sum": 3605.0, "min": 3605}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1585653339.2609, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1585653339.135056}
#
# [03/31/2020 11:15:39 INFO 140708599981888] #throughput_metric: host=algo-1, train throughput=1800.50152704 records/second
# [03/31/2020 11:15:39 WARNING 140708599981888] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/31/2020 11:15:39 WARNING 140708599981888] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/31/2020 11:15:39 INFO 140708599981888] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=42.2806178502
# [03/31/2020 11:15:39 INFO 140708599981888] #validation_score (algo-1) : ('mse_objective', 34.939134870256694)
# [03/31/2020 11:15:39 INFO 140708599981888] #validation_score (algo-1) : ('mse', 34.939134870256694)
# [03/31/2020 11:15:39 INFO 140708599981888] #validation_score (algo-1) : ('absolute_loss', 3.8986644744873047)
# [03/31/2020 11:15:39 INFO 140708599981888] #quality_metric: host=algo-1, validation mse_objective <loss>=34.9391348703
# [03/31/2020 11:15:39 INFO 140708599981888] #quality_metric: host=algo-1, validation mse <loss>=34.9391348703
# [03/31/2020 11:15:39 INFO 140708599981888] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.89866447449
# [03/31/2020 11:15:39 INFO 140708599981888] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [03/31/2020 11:15:39 INFO 140708599981888] Saved checkpoint to "/tmp/tmpvhX8XE/mx-mod-0000.params"
# [03/31/2020 11:15:39 INFO 140708599981888] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1459.4941139221191, "sum": 1459.4941139221191, "min": 1459.4941139221191}, "finalize.time": {"count": 1, "max": 74.45883750915527, "sum": 74.45883750915527, "min": 74.45883750915527}, "initialize.time": {"count": 1, "max": 144.6249485015869, "sum": 144.6249485015869, "min": 144.6249485015869}, "check_early_stopping.time": {"count": 15, "max": 1.1758804321289062, "sum": 7.664680480957031, "min": 0.1780986785888672}, "setuptime": {"count": 1, "max": 26.766061782836914, "sum": 26.766061782836914, "min": 26.766061782836914}, "update.time": {"count": 14, "max": 125.07104873657227, "sum": 1141.218662261963, "min": 63.46392631530762}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1585653339.348203, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1585653337.967933}
# 2020-03-31 11:15:48 Completed - Training job completed
# Training seconds: 46
# Billable seconds: 46

# %% [markdown]
# ## 第 6 (B) 步：部署训练过的模型
#
# 与 XGBoost 模型相似，拟合模型后，我们需要部署模型。并且与 XGBoost 模型一样，我们将使用低阶方法，这样可以更好地控制端点创建过程。
#
# ### 构建模型
# 在部署模型之前，我们需要先创建模型。我们之前使用的 `fit` 方法创建了一些模型工件，我们可以使用这些工件构建模型对象。

# %%
# First, we create a unique model name
linear_model_name = "boston-update-linear-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the linear-learner container that we used for training
# can also be used for inference.
linear_primary_container = {
    "Image": linear_container,
    "ModelDataUrl": linear.model_data
}

# And lastly we construct the SageMaker model
linear_model_info = session.sagemaker_client.create_model(
                                ModelName = linear_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = linear_primary_container)

# %% [markdown]
# ### 创建端点配置
#
# 创建了模型之后，我们将创建端点配置，从而创建端点。

# %%
# As before, we need to give our endpoint configuration a name which should be unique
linear_endpoint_config_name = "boston-linear-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
linear_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = linear_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": linear_model_name,
                                "VariantName": "Linear-Model"
                            }])

# %% [markdown]
# ### 部署端点
#
# 创建了端点配置后，我们可以要求 SageMaker 构建端点了。
#
# **注意：**再次友好提醒你，你即将部署端点。使用完毕后，请记得关闭端点！

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = linear_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -----------!

# %% [markdown]
# ## 第 7 (B) 步：使用模型
#
# 与 XGBoost 模型一样，我们将向端点发送一些数据，看看能否正常运行。需要注意的是，线性模型的输出格式与 XGBoost 模型的不同。

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0d38ffd0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:23:55 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'eb92cf38-f6a2-409e-8840-2948322f3306'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'eb92cf38-f6a2-409e-8840-2948322f3306',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '{"predictions": [{"score": 26.73609733581543}]}'

# %%
Y_test.values[0]
# Out:
# array([24.6])

# %% [markdown]
# ## 关闭端点
#
# 现在我们知道线性模型的端点能运行，我们可以关闭端点了。

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '01b4cb10-c4d3-43a4-9596-b07b02fc2a2b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '01b4cb10-c4d3-43a4-9596-b07b02fc2a2b',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Tue, 31 Mar 2020 11:24:00 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## 第 6 (C) 步：部署组合模型
#
# 到目前为止，我们构建了两个可以部署和使用的不同模型。在讲解如何使部署的端点从一个端点配置切换到另一个配置之前，先考虑一个稍微不同的情形。假设在从仅使用 XGBoost 切换到仅使用线性模型之前，我们首先想要执行 A/B 测试，将某些输入数据发送给 XGBoost 模型，将某些数据发送给线性模型。
#
# 幸运的是，SageMaker 提供了这样的功能。并且方法与部署模型差别不大。唯一区别是我们需要在端点配置的生产变体参数中列出多个模型。
#
# 有个问题值得思考，要向在生产变体参数中列出的每个模型发送多少数据？答案是取决于每个模型的权重。
#
# 假设在生产变体参数中列出了 $k$ 个模型，每个模型 $i$ 的权重为 $w_i$。那么每个模型 $i$ 将获得 $w_i / W$ 的数据，其中 $W = \sum_{i} w_i$。
#
# 因为我们有两个模型：线性模型和 XGBoost 模型，并且每个模型的权重为 1，所以每个模型将从发送给端点的数据中获得 1 / (1 + 1) = 1/2 的数据。

# %%
# As before, we need to give our endpoint configuration a name which should be unique
combined_endpoint_config_name = "boston-combined-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
combined_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = combined_endpoint_config_name,
                            ProductionVariants = [
                                { # First we include the linear model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": linear_model_name,
                                    "VariantName": "Linear-Model"
                                }, { # And next we include the xgb model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": xgb_model_name,
                                    "VariantName": "XGB-Model"
                                }])

# %% [markdown]
# 创建了端点配置后，我们可以要求 SageMaker 构建端点了。
#
# **注意：**再次友好提醒你，你即将部署端点。使用完毕后，请记得关闭端点！

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = combined_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------!

# %% [markdown]
# ## 第 7 (C) 步：使用模型
#
# 我们构建了向 XGBoost 模型和线性模型发送数据的端点，下面可以向端点发送一些数据，看看结果如何。

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e584780>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Tue, 31 Mar 2020 11:31:04 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '84bccf7b-8ace-4b62-ac4d-e40724074b58'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '84bccf7b-8ace-4b62-ac4d-e40724074b58',
#                       'RetryAttempts': 0}}

# %% [markdown]
# 因为查看一个响应结果并不足以了解运行状况，所以我们将查看几个不同的端点响应结果。

# %%
for rec in range(10):
    response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[rec])))
    pprint(response)
    result = response['Body'].read().decode("utf-8")
    print(result)
    print(Y_test.values[rec])
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e57a6a0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '76133065-7f94-4dfa-8a02-b592c13a46c5'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '76133065-7f94-4dfa-8a02-b592c13a46c5',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 26.73609733581543}]}
# [24.6]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e57a400>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'cca5ae09-b0e1-498f-b045-2fd79b36653f'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cca5ae09-b0e1-498f-b045-2fd79b36653f',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 19.876407623291016}]}
# [17.2]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e5f0a20>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '71243e63-6367-4fdc-b538-aff983710737'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '71243e63-6367-4fdc-b538-aff983710737',
#                       'RetryAttempts': 0}}
# 43.1974449158
# [43.8]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e5f0550>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'b5501119-522e-449a-9e40-e053056b5b93'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'b5501119-522e-449a-9e40-e053056b5b93',
#                       'RetryAttempts': 0}}
# 23.6268844604
# [23.3]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e5f0710>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'cde68f41-72e1-4232-919c-016a8e692942'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cde68f41-72e1-4232-919c-016a8e692942',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 15.429569244384766}]}
# [15.6]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e5f0d30>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '823ddad2-8a80-4e4d-a09e-b05695deab43'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '823ddad2-8a80-4e4d-a09e-b05695deab43',
#                       'RetryAttempts': 0}}
# 35.9862861633
# [32.7]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0dcb0c50>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'f47eed96-ea1b-4c08-a794-cb332aeb48a7'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'f47eed96-ea1b-4c08-a794-cb332aeb48a7',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 23.710113525390625}]}
# [20.8]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0dcb0a20>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '94b1e7ae-78cc-45da-be19-794e898930b2'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '94b1e7ae-78cc-45da-be19-794e898930b2',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 21.48716163635254}]}
# [21.4]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e584470>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '0900d1eb-6a72-415e-be11-726509e8415f'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0900d1eb-6a72-415e-be11-726509e8415f',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 18.687305450439453}]}
# [14.1]
# {'Body': <botocore.response.StreamingBody object at 0x7f7e0e5f0fd0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 31 Mar 2020 11:31:06 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '5a289486-b8c0-4913-82dd-6e31d4a46dba'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '5a289486-b8c0-4913-82dd-6e31d4a46dba',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 19.64293098449707}]}
# [18.2]

# %% [markdown]
# 如果我们不记得部署端点的属性后，可以使用 `describe_endpoint` 函数来要求 SageMaker 返回部署端点的描述信息。

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 3, 31, 11, 24, 4, 276000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:270372225889:endpoint/boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-03-31-11-24-02',
#  'EndpointName': 'boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 3, 31, 11, 30, 12, 146000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 3, 31, 11, 24, 5, 971000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:1cc553330fc7ab939e72cc0c0ed4bed61bbb2e7b33b4f838cb0a146d0bb5da9c',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 3, 31, 11, 24, 6, 146000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost@sha256:513e8442b35b9ecc9d326f85659f8e30b10e2cec096b863f04a9738baa9ebb57',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Tue, 31 Mar 2020 11:31:09 GMT',
#                                       'x-amzn-requestid': '47fdeeba-c3e3-4a16-90d0-cfc368d9374d'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '47fdeeba-c3e3-4a16-90d0-cfc368d9374d',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## 更新端点
#
# 假设我们执行了 A-B 测试，并且新线性模型效果不错。现在我们将使端点从同时向 XGBoost 模型和线性模型发送数据切换到仅向线性模型发送数据。
#
# 但是我们不希望真正地关闭端点，因为这样会干扰依赖于端点的服务。我们可以要求 SageMaker 将端点**更新**成新的端点配置。
#
# SageMaker 将使用新的配置设置新的端点。新端点运行后，SageMaker 将切换旧端点，使其指向新部署的模型，并确保整个流程在后台无缝发生。

# %%
session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)
# Out:
# {'EndpointArn': 'arn:aws:sagemaker:us-west-1:270372225889:endpoint/boston-update-endpoint-2020-03-31-11-24-04',
#  'ResponseMetadata': {'RequestId': '6439f433-93a6-4c4f-b98b-b65eec76dd80',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6439f433-93a6-4c4f-b98b-b65eec76dd80',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '110',
#    'date': 'Tue, 31 Mar 2020 11:31:13 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# 要了解所发生的情况，在更新流程结束之前，我们可以要求 SageMaker 描述目前正在使用的端点。我们发现正在使用的端点依然具有和之前一样的特性。

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 3, 31, 11, 24, 4, 276000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:270372225889:endpoint/boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-03-31-11-24-02',
#  'EndpointName': 'boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointStatus': 'Updating',
#  'LastModifiedTime': datetime.datetime(2020, 3, 31, 11, 31, 13, 983000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 3, 31, 11, 24, 5, 971000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:1cc553330fc7ab939e72cc0c0ed4bed61bbb2e7b33b4f838cb0a146d0bb5da9c',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 3, 31, 11, 24, 6, 146000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost@sha256:513e8442b35b9ecc9d326f85659f8e30b10e2cec096b863f04a9738baa9ebb57',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1161',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Tue, 31 Mar 2020 11:31:15 GMT',
#                                       'x-amzn-requestid': 'c55af530-f3fe-4013-95f4-0e47d761ee4f'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c55af530-f3fe-4013-95f4-0e47d761ee4f',
#                       'RetryAttempts': 0}}

# %% [markdown]
# 如果现在等待更新流程完成，然后要求 SageMaker 描述端点，它将返回新端点的特性。

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------!

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 3, 31, 11, 24, 4, 276000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:270372225889:endpoint/boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointConfigName': 'boston-linear-endpoint-config-2020-03-31-11-16-51',
#  'EndpointName': 'boston-update-endpoint-2020-03-31-11-24-04',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 3, 31, 11, 37, 23, 209000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 3, 31, 11, 31, 15, 848000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:1cc553330fc7ab939e72cc0c0ed4bed61bbb2e7b33b4f838cb0a146d0bb5da9c',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '770',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Tue, 31 Mar 2020 11:37:53 GMT',
#                                       'x-amzn-requestid': 'c218eabf-122f-421f-8f4d-bb90224c207c'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c218eabf-122f-421f-8f4d-bb90224c207c',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## 关闭端点
#
# 使用完毕后，我们需要关闭端点。

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'd28bbe65-fbf9-4042-a1f3-72417ef0d487',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd28bbe65-fbf9-4042-a1f3-72417ef0d487',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Tue, 31 Mar 2020 11:37:58 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## 可选步骤：清理数据
#
# SageMaker 上的默认 notebook 实例没有太多的可用磁盘空间。当你继续完成和执行 notebook 时，最终会耗尽磁盘空间，导致难以诊断的错误。完全使用完 notebook 后，建议删除创建的文件。你可以从终端或 notebook hub 删除文件。以下单元格中包含了从 notebook 内清理文件的命令。

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir
